# %% [markdown]
# ##Introduction to the IFC models
#
# In this notebook you will find links and 3D visualisations of the models, their elements and their properties.

# %% [markdown]
# ###NEST's HiLo unit
# Run the code cell bellow to display the model in 3D:

# %%
from IPython.display import IFrame

IFrame(src='https://app.speckle.systems/projects/85e791d39b/models/9821f8d175@fb5f9776f5', width=900, height=700)
# Out:
#         <iframe
#             width="1500"
#             height="700"
#             src="https://app.speckle.systems/projects/85e791d39b/models/9821f8d175@fb5f9776f5"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Link to the model:https://app.speckle.systems/projects/85e791d39b/models/9821f8d175@fb5f9776f5

# %% [markdown]
# ###LTU
# Run the code cell bellow to display the model in 3D:

# %%
from IPython.display import IFrame

IFrame(src='https://app.speckle.systems/projects/85e791d39b/models/0f27000266', width=900, height=700)
# Out:
#         <iframe
#             width="1500"
#             height="700"
#             src="https://app.speckle.systems/projects/85e791d39b/models/0f27000266"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Link to the model: https://app.speckle.systems/projects/85e791d39b/models/0f27000266

# %% [markdown]
# ###Duplex
# Run the code cell bellow to display the model in 3D:

# %%
from IPython.display import IFrame

IFrame(src='https://app.speckle.systems/projects/85e791d39b/models/96915a1c17', width=900, height=700)
# Out:
#         <iframe
#             width="1500"
#             height="700"
#             src="https://app.speckle.systems/projects/85e791d39b/models/96915a1c17"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Link to the model: https://app.speckle.systems/projects/85e791d39b/models/96915a1c17

# %% [markdown]
# ###KIT_SimleyWest
# Run the code cell bellow to display the model in 3D:

# %%
from IPython.display import IFrame

IFrame(src='https://app.speckle.systems/projects/85e791d39b/models/8851c15025', width=900, height=700)
# Out:
#         <iframe
#             width="1500"
#             height="700"
#             src="https://app.speckle.systems/projects/85e791d39b/models/8851c15025"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Link to the model: https://app.speckle.systems/projects/85e791d39b/models/8851c15025

# %% [markdown]
# ##Element navigation instructions

# %% [markdown]
# In order to find specific elements, navigate to the "Scene explorer" button as shown below:
#
# <img width="350" src="......"/>

# %% [markdown]
# Then, to search for a property by which to filter, click on "Object Type" as shown bellow:
#
# <img width="350" src="data:image/png;base64,..."/>

# %% [markdown]
# To find a specific element inside the model, we can use its unique identifier. To do so, type in and select "applicationId", and select the first option as shown bellow:
#
# <img width="350" src="data:image/png;base64,..."/>

# %% [markdown]
# The Id of each element is located in the Id column of the provided excel sheet. Use this value to find the element in the model as shown below:
#
# <img width="850" src="data:image/png;base64,..."/>

# %% [markdown]
# To locate the element and inspect its properties, select the search result as shown below:
#
# <img width="950" src="data:image/png;base64,..."/>
